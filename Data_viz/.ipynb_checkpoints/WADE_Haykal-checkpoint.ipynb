# %% [markdown]
# # Master Data Science Data_VIZ
# ### WADE El Hadji Malick
# ### HAYKAL Fayad

# %% [markdown]
# ## 1. Nettoyage des données

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

path_School = "/users/mmath/wade/Bureau/Master_DS/Projets/Data_viz/Synthese_donnees_des_semis.csv"
path_Malick = "/home/malick/Bureau/Projets/Projets_Malick_fayad/Data_viz/Synthese_donnees_des_semis.csv"

df = pd.read_csv(path_Malick,  sep='\t',  decimal=",")

df.head(10)
# Out:
#    Bancs  camera  zone     Pop  5_degres_C_TMG_h  5_degres_C_TMG_j  \
# 0    3.0     1.0  11.0  Témoin            414.00             17.25
# 1    3.0     2.0  11.0  Témoin            430.86             17.95
# 2    3.0     3.0  11.0  Témoin            382.86             15.95
# 3    3.0     4.0  11.0  Témoin            420.00             17.50
# 4    4.0     1.0  11.0  Témoin            432.89             18.04
# 5    4.0     2.0  11.0  Témoin            413.82             17.24
# 6    4.0     3.0  11.0  Témoin            446.80             18.62
# 7    4.0     4.0  11.0  Témoin            429.60             17.90
# 8    3.0     1.0  11.0  Témoin            354.22             14.76
# 9    3.0     2.0  26.0  Témoin            377.78             15.74
#
#    Aire_sous_la_courbe  15_j  16_j  17_j  18_j  19_j  20_j  21_j
# 0               2652.0   4.0  16.0  20.0  24.0  32.0  36.0  40.0
# 1               2652.0   0.0   4.0   4.0  12.0  24.0  28.0  28.0
# 2               2652.0   8.0  12.0  20.0  20.0  20.0  24.0  28.0
# 3               2652.0   4.0   4.0   4.0   4.0  12.0  16.0  16.0
# 4               2646.0   4.0   4.0  16.0  16.0  24.0  32.0  36.0
# 5               2646.0   8.0  12.0  20.0  32.0  36.0  36.0  44.0
# 6               2646.0   4.0   4.0   8.0  16.0  20.0  24.0  40.0
# 7               2646.0   0.0   0.0   8.0   8.0  12.0  20.0  20.0
# 8               5731.2  16.0  28.0  28.0  32.0  36.0  36.0  36.0
# 9               5731.2  12.0  20.0  20.0  20.0  32.0  36.0  36.0

# %%
print ("Lignes: " ,df.shape[0])
print ("Colonnes: " ,df.shape[1])
print("---------------")
print ("\nVariables:")
print(df.dtypes)
print ("\nValeurs uniques :")
print(df.nunique())
# Out:
# Lignes:  961
# Colonnes:  14
# ---------------
#
# Variables:
# Bancs                  float64
# camera                 float64
# zone                   float64
# Pop                     object
# 5_degres_C_TMG_h       float64
# 5_degres_C_TMG_j       float64
# Aire_sous_la_courbe    float64
# 15_j                   float64
# 16_j                   float64
# 17_j                   float64
# 18_j                   float64
# 19_j                   float64
# 20_j                   float64
# 21_j                   float64
# dtype: object
#
# Valeurs uniques :
# Bancs                    2
# camera                   4
# zone                    24
# Pop                      6
# 5_degres_C_TMG_h       699
# 5_degres_C_TMG_j       365
# Aire_sous_la_courbe    686
# 15_j                    17
# 16_j                    20
# 17_j                    22
# 18_j                    23
# 19_j                    23
# 20_j                    24
# 21_j                    25
# dtype: int64

# %%
print ("\nTotal des valeurs manquantes :  ",df.isnull().sum().values.sum())

print("\n")
print(df.isnull().sum())
# Out:
# Total des valeurs manquantes :   16
#
#
# Bancs                  1
# camera                 1
# zone                   1
# Pop                    1
# 5_degres_C_TMG_h       2
# 5_degres_C_TMG_j       2
# Aire_sous_la_courbe    1
# 15_j                   1
# 16_j                   1
# 17_j                   1
# 18_j                   1
# 19_j                   1
# 20_j                   1
# 21_j                   1
# dtype: int64

# %% [markdown]
# On voit que notre jeux de données posséde des lignes avec avec au moins un e valeur manquante.
# On choisit de les supprimer, ce qui représente une perte de 2 lignes d'observations de données

# %%
Perte_de_donnees = df.shape[0]
df = df.dropna()

Perte_de_donnees = (Perte_de_donnees - df.shape[0])/100

print("En supprimant les lignes avec des valeurs manquantes, on a une perte de données de ", Perte_de_donnees,"%")
# Out:
# En supprimant les lignes avec des valeurs manquantes, on a une perte de données de  0.02 %

# %%
df.isnull().sum()
# Out:
# Bancs                  0
# camera                 0
# zone                   0
# Pop                    0
# 5_degres_C_TMG_h       0
# 5_degres_C_TMG_j       0
# Aire_sous_la_courbe    0
# 15_j                   0
# 16_j                   0
# 17_j                   0
# 18_j                   0
# 19_j                   0
# 20_j                   0
# 21_j                   0
# dtype: int64

# %%
import seaborn as sns

Col_pairplot = ["5_degres_C_TMG_h", "5_degres_C_TMG_j", "Aire_sous_la_courbe", "15_j", "16_j", "17_j", "18_j", "19_j", "20_j", "21_j"]

sns.set(style="ticks", color_codes=True)
g = sns.pairplot(df[Col_pairplot])

# %% [markdown]
# ## 2. Réduction de dimensions

# %%
import matplotlib.pyplot as plt

fig = plt.figure(1, figsize=(12, 12))

sns.heatmap(round(df[Col_pairplot].corr(),2), annot=True, fmt=".2f")
plt.show()

# %% [raw]
# On remarque que plusieurs variables sont fortement corrélées entre elles et deux variables sont parfaitement corrélée("5_degres_C_TMG_h" et "5_degres_C_TMG_h").
# On supprime la variable df["5_degres_C_TMG_h"]

# %%
df.drop(["5_degres_C_TMG_h"], axis = 1, inplace = True)

# %% [markdown]
# ### a. ACP compléte

# %%
#classe pour standardisation(On centre et réduis nos valeurs)
from sklearn.preprocessing import StandardScaler

Col_ACP = ["5_degres_C_TMG_j", "Aire_sous_la_courbe", "15_j", "16_j", "17_j", "18_j", "19_j", "20_j", "21_j"]

#instanciation
sc = StandardScaler()

#transformation – centrage-réduction
df_ACP = sc.fit_transform(df[Col_ACP])

# %%
#vérification

#moyenne
print(np.around(np.mean(df_ACP,axis=0),3))
# Out:
# [ 0.  0. -0.  0.  0.  0.  0.  0. -0.]

# %%
#écart-type
print(np.std(df_ACP,axis=0,ddof=0))
# Out:
# [1. 1. 1. 1. 1. 1. 1. 1. 1.]

# %% [raw]
# Nous sommes maintenant parés pour lancer l’ACP.

# %%
#classe pour l'ACP
from sklearn.decomposition import PCA

#instanciation
acp = PCA(n_components=2)
acp.fit(df_ACP)
#calculs
ACP_complete = acp.transform(df_ACP)

#nombre de composantes calculées
print(acp.n_components_)
# Out:
# 2

# %%
#proportions de variance associées aux axes
acp.explained_variance_ratio_
# Out:
# array([0.85946909, 0.09887898])

# %%
print(round(sum(acp.explained_variance_ratio_),4))
# Out:
# 0.9583

# %% [markdown]
# On voit que Les deux premières composantes accapare 95.83% de l’information disponible.

# %%
df_ACP_complete = pd.DataFrame(ACP_complete, columns=['X1','X2'])

# %%
Col = ["Bancs", "camera", "zone", "Pop"]
df_ACP_complete = pd.concat([df[Col], df_ACP_complete], axis=1)

# %%
print ("\nTotal des valeurs manquantes :  ",df_ACP_complete.isnull().sum().values.sum())

print("\n")
print(df_ACP_complete.isnull().sum())
# Out:
# Total des valeurs manquantes :   0
#
#
# Bancs     0
# camera    0
# zone      0
# Pop       0
# X1        0
# X2        0
# dtype: int64

# %%
df_ACP_complete = df_ACP_complete.dropna()

# %%
df_ACP_complete[["Bancs", "camera", "zone"]] = df_ACP_complete[["Bancs", "camera", "zone"]].astype(int)
df_ACP_complete.head()
# Out:
#    Bancs  camera  zone     Pop        X1        X2
# 0      3       1    11  Témoin -2.113743 -0.523574
# 1      3       2    11  Témoin -3.634503 -0.743552
# 2      3       3    11  Témoin -2.494291  1.035894
# 3      3       4    11  Témoin -4.198362  0.291485
# 4      4       1    11  Témoin -3.049244 -0.927663

# %% [markdown]
# ### a. ACP partielle

# %%
Col_ACP = ["15_j", "16_j", "17_j", "18_j", "19_j", "20_j", "21_j"]

#instanciation
acp = PCA(n_components=1)

#calculs
acp.fit(df[Col_ACP])
ACP_parielle = acp.transform(df[Col_ACP])

#proportions de variance associées à la premiére
print("Proportion de variance associée à la premiére axe:",round(sum(acp.explained_variance_ratio_),4))
# Out:
# Proportion de variance associée à la premiére axe: 0.9243

# %%
df_partielle = pd.DataFrame(ACP_parielle, columns=['ACP_j']) 
Col = ["Bancs", "camera", "zone", "Pop", "5_degres_C_TMG_j", "Aire_sous_la_courbe"]
df_ACP_parielle = pd.concat([df[Col], df_partielle], axis=1)

# %%
fig = plt.figure(1, figsize=(5, 5))

sns.heatmap(round(df_ACP_parielle[["5_degres_C_TMG_j", "Aire_sous_la_courbe", "ACP_j"]].corr(),2), annot=True, fmt=".2f")
plt.show()

# %% [raw]
# La variable "Aire_sous_la_courbe" est fortement corrélée avec la variable "ACP_j" (ce qui est plûtot rassurant). On décide de supprimer la variable "Aire_sous_la_courbe".

# %%
df_ACP_parielle.drop(["Aire_sous_la_courbe"], axis = 1, inplace = True)

# %%
print ("\nTotal des valeurs manquantes :  ",df_ACP_parielle.isnull().sum().values.sum())

print("\n")
print(df_ACP_parielle.isnull().sum())
# Out:
# Total des valeurs manquantes :   0
#
#
# Bancs               0
# camera              0
# zone                0
# Pop                 0
# 5_degres_C_TMG_j    0
# ACP_j               0
# dtype: int64

# %%
df_ACP_parielle = df_ACP_parielle.dropna()

# %%
df_ACP_parielle[["Bancs", "camera", "zone"]] = df_ACP_parielle[["Bancs", "camera", "zone"]].astype(int)
df_ACP_parielle.head()
# Out:
#    Bancs  camera  zone     Pop  5_degres_C_TMG_j      ACP_j
# 0      3       1    11  Témoin             17.25 -29.347070
# 1      3       2    11  Témoin             17.95 -56.953843
# 2      3       3    11  Témoin             15.95 -46.399069
# 3      3       4    11  Témoin             17.50 -74.363199
# 4      4       1    11  Témoin             18.04 -44.776618

# %% [markdown]
# ## 3. Graphes

# %% [markdown]
# ### a. graphe avec une ACP compléte

# %%
print ("\nValeurs uniques :")
print(df.nunique())
# Out:
# Valeurs uniques :
# Bancs                    2
# camera                   4
# zone                    24
# Pop                      6
# 5_degres_C_TMG_j       365
# Aire_sous_la_courbe    685
# 15_j                    17
# 16_j                    20
# 17_j                    22
# 18_j                    23
# 19_j                    23
# 20_j                    23
# 21_j                    24
# dtype: int64

# %%
Y = ["Bancs", "camera", "zone"]
i = 1

sns.set(style="darkgrid")
filled_markers = ('o', 'X', '<',  'D','8', 's', 'p', '*', 'h', '>', 'H', 'd', 'P', '^')
plt.figure(figsize=(12,12))
sns.scatterplot(x="X1", y="X2", hue="Pop", style = Y[i], palette="viridis", markers=filled_markers, data=df_ACP_complete, s =50)

# %% [markdown]
# ### b. graphe avec une ACP partielle

# %%
print ("\nValeurs uniques :")
print(df.nunique())
df_ACP_parielle.head()
# Out:
# Valeurs uniques :
# Bancs                    2
# camera                   4
# zone                    24
# Pop                      6
# 5_degres_C_TMG_j       365
# Aire_sous_la_courbe    685
# 15_j                    17
# 16_j                    20
# 17_j                    22
# 18_j                    23
# 19_j                    23
# 20_j                    23
# 21_j                    24
# dtype: int64
#    Bancs  camera  zone     Pop  5_degres_C_TMG_j      ACP_j
# 0      3       1    11  Témoin             17.25 -29.347070
# 1      3       2    11  Témoin             17.95 -56.953843
# 2      3       3    11  Témoin             15.95 -46.399069
# 3      3       4    11  Témoin             17.50 -74.363199
# 4      4       1    11  Témoin             18.04 -44.776618

# %%
Y = ["Bancs", "camera", "zone"]
i = 1

sns.set(style="darkgrid")
filled_markers = ('o', 'X', '<',  'D','8', 's', 'p', '*', 'h', '>', 'H', 'd', 'P', '^')
plt.figure(figsize=(12,12))
sns.scatterplot(x="5_degres_C_TMG_j", y="ACP_j", hue="Pop", style = Y[i], palette="viridis", markers=filled_markers, data=df_ACP_parielle, s =50)

# %% [markdown]
# ## 4. Prédictions

# %% [raw]
# Une tranformation des variables est necéssaire. Icic toutes les variables de types 'Object' seront indexées.

# %%
import time
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.externals import joblib # save and load models

# %%
def object_to_int(dataframe_series):
    """une simple fonction d'indexation"""
    
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
Col_X = ["Pop", "zone", "5_degres_C_TMG_j", "Aire_sous_la_courbe", "15_j", "16_j", "17_j", "18_j", "19_j", "20_j", "21_j"]
Col_Y = ["Bancs", "camera", "zone"]

df = df.apply(lambda x: object_to_int(x))
df[["Bancs", "camera", "zone"]] = df[["Bancs", "camera", "zone"]].astype(int)

df.head()
# Out:
#    Bancs  camera  zone  Pop  5_degres_C_TMG_j  Aire_sous_la_courbe  15_j  \
# 0      3       1    11    5             17.25               2652.0   4.0
# 1      3       2    11    5             17.95               2652.0   0.0
# 2      3       3    11    5             15.95               2652.0   8.0
# 3      3       4    11    5             17.50               2652.0   4.0
# 4      4       1    11    5             18.04               2646.0   4.0
#
#    16_j  17_j  18_j  19_j  20_j  21_j
# 0  16.0  20.0  24.0  32.0  36.0  40.0
# 1   4.0   4.0  12.0  24.0  28.0  28.0
# 2  12.0  20.0  20.0  20.0  24.0  28.0
# 3   4.0   4.0   4.0  12.0  16.0  16.0
# 4   4.0  16.0  16.0  24.0  32.0  36.0

# %%
print ("Lignes: " ,df.shape[0])
print ("Colonnes: " ,df.shape[1])
print("---------------")
print ("\nVariables:")
print(df.dtypes)
print ("\nValeurs uniques :")
print(df.nunique())
# Out:
# Lignes:  959
# Colonnes:  13
# ---------------
#
# Variables:
# Bancs                    int64
# camera                   int64
# zone                     int64
# Pop                      int64
# 5_degres_C_TMG_j       float64
# Aire_sous_la_courbe    float64
# 15_j                   float64
# 16_j                   float64
# 17_j                   float64
# 18_j                   float64
# 19_j                   float64
# 20_j                   float64
# 21_j                   float64
# dtype: object
#
# Valeurs uniques :
# Bancs                    2
# camera                   4
# zone                    24
# Pop                      6
# 5_degres_C_TMG_j       365
# Aire_sous_la_courbe    685
# 15_j                    17
# 16_j                    20
# 17_j                    22
# 18_j                    23
# 19_j                    23
# 20_j                    23
# 21_j                    24
# dtype: int64

# %%
X = df[Col_X]
y = df[Col_Y]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state = 40)

# %% [markdown]
# #### a. KNN

# %%
#on crée un nouveau modèle knn
knn = KNeighborsClassifier()

max_Voisins = 101

#on crée un dictionnaire de toutes les valeurs que nous voulons tester avec n_neighbors
param_grid_KNN = {"n_neighbors": np.arange(1, max_Voisins), "weights" : ["uniform", "distance"]}

#on utilise gridsearch pour tester toutes les valeurs de n_neighbors
knn_gscv = GridSearchCV(knn, param_grid_KNN, cv=5, n_jobs=-1, verbose=10)

#ajustement du modèle aux données
t_debut = time.time()
knn_gscv.fit(X_train,y_train["Bancs"])
t_fin = time.time()

temps_knn = (t_fin - t_debut)/60

print("Précision Train: ",round(knn_gscv.score(X_train,y_train["Bancs"]),3))
print("Précision Test: ",round(knn_gscv.score(X_test,y_test["Bancs"]),3))
print("\n")

print(knn_gscv.best_params_)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1881s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1510s.) Setting batch_size=4.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 308 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 368 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 436 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 580 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 740 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 824 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 916 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:   13.6s finished
# Précision Train:  0.577
# Précision Test:  0.575
#
#
# {'n_neighbors': 100, 'weights': 'uniform'}

# %% [markdown]
# #### b. LogisticRegression

# %%
#on crée un nouveau modèle logit

Logit = LogisticRegression(class_weight='balanced')

#on crée un dictionnaire de toutes les valeurs que nous voulons tester
param_grid_Logit = {
                    "penalty": ['l2'],
                    "C": [0.01,1,10,20,50,100,500,1000,10000],
                    "max_iter": [100, 200],
                    "solver": ['newton-cg', 'sag', 'saga', 'lbfgs'],
                    "multi_class": ['ovr', 'multinomial', 'auto']
                   }

#on utilise gridsearch pour tester toutes les valeurs de param_grid
Logit_gscv = GridSearchCV(Logit, param_grid_Logit, cv=5, n_jobs=-1, verbose=10)

#ajustement du modèle aux données
t_debut = time.time()
Logit_gscv.fit(X_train,y_train["Bancs"])
t_fin = time.time()

temps_Logit = (t_fin - t_debut)/60

print("Précision Train: ",round(Logit_gscv.score(X_train,y_train["Bancs"]),3))
print("Précision Test: ",round(Logit_gscv.score(X_test,y_test["Bancs"]),3))
print("\n")

print(Logit_gscv.best_params_)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    9.9s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   19.3s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:   35.1s
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:   39.4s
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:   41.4s
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:   44.5s
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:   46.8s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:   48.8s
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:   57.1s
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed:  1.1min finished
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# Précision Train:  0.574
# Précision Test:  0.625
#
#
# {'C': 1, 'max_iter': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:462: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /home/malick/.local/lib/python3.6/site-packages/scipy/optimize/linesearch.py:313: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)

# %% [markdown]
# #### c. Gradient Boosting

# %%
#on crée un nouveau modèle gradient Boosting
GB = GradientBoostingClassifier()

#on crée un dictionnaire de toutes les valeurs que nous voulons tester
param_grid_GB = {
                  "learning_rate" : [0.001, 0.01, 0.05, 0.1, 0.5],
                  "n_estimators": [50, 100, 200],
                  "subsample": [0.5,1.0], 
                  "max_depth": [4, 6, 8], 
                  "max_features": [0.25, 0.5, 0.75, 1.0]
                   }

#on utilise gridsearch pour tester toutes les valeurs de param_grid
GB_gscv = GridSearchCV(GB, param_grid_GB, cv=5, n_jobs=-1, verbose=10)

#ajustement du modèle aux données
t_debut = time.time()
GB_gscv.fit(X_train,y_train["Bancs"])
t_fin = time.time()

temps_GB = (t_fin - t_debut)/60

print("Précision Train: ",round(GB_gscv.score(X_train,y_train["Bancs"]),3))
print("Précision Test: ",round(GB_gscv.score(X_test,y_test["Bancs"]),3))
print("\n")

print(GB_gscv.best_params_)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   10.2s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   17.8s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   28.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   39.5s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 1800 out of 1800 | elapsed:  9.0min finished
# /home/malick/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Précision Train:  0.709
# Précision Test:  0.625
#
#
# {'learning_rate': 0.01, 'max_depth': 4, 'max_features': 0.5, 'n_estimators': 100, 'subsample': 0.5}

# %% [markdown]
# ##### d. SVM Linear

# %%
#on crée un nouveau modèle SVM à noyau Polynomiale
svmLINEAR = SVC(kernel='linear',class_weight='balanced',probability=True)

#on crée un dictionnaire de toutes les valeurs que nous voulons tester
param_grid_LINEAR = {"C": [0.01,1,10,20,50,100,500,1000,10000]}

#on utilise gridsearch pour tester toutes les valeurs
svmLINEAR_gscv = GridSearchCV(svmLINEAR, param_grid_LINEAR, cv=5, n_jobs=-1, verbose=10)

#ajustement du modèle aux données
t_debut = time.time()
svmLINEAR_gscv.fit(X_train,y_train["Bancs"])
t_fin = time.time()

temps_SVM_Linear = (t_fin - t_debut)/60

print("Précision Train: ",round(svmLINEAR_gscv.score(X_train,y_train["Bancs"]),3))
print("Précision Test: ",round(svmLINEAR_gscv.score(X_test,y_test["Bancs"]),3))
print("\n")
print(svmLINEAR_gscv.best_params_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-ccb7c1c55b92> in <module>
#      10 #ajustement du modèle aux données
#      11 t_debut = time.time()
# ---> 12 svmLINEAR_gscv.fit(X_train,y_train["Bancs"])
#      13 t_fin = time.time()
#      14
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     685                 return results
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#     689         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1146     def _run_search(self, evaluate_candidates):
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#    1150
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     664                                for parameters, (train, test)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#     668                 if len(out) < 1:
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /usr/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### e. SVM Poly

# %%
#on crée un nouveau modèle SVM à noyau Polynomiale
svmPOLY = SVC(kernel='poly',class_weight='balanced', probability=True)

#on crée un dictionnaire de toutes les valeurs que nous voulons tester
param_grid_POLY = {
                   "C": [0.01,1,10,20,50,100,500,1000],
                   "gamma" : np.arange(0,1.1,0.1),
                   "degree": [2,3,4,6],
                   "coef0": np.arange(0,1,0.5)
                   }

#on utilise gridsearch pour tester toutes les valeurs
svmPOLY_gscv = GridSearchCV(svmPOLY, param_grid_POLY, cv=5, n_jobs=-1, verbose=10)

#ajustement du modèle aux données
t_debut = time.time()
svmPOLY_gscv.fit(X_train,y_train["Bancs"])
t_fin = time.time()

temps_SVM_Poly = (t_fin - t_debut)/60

print("Précision Train: ",round(svmPOLY_gscv.score(X_train,y_train["Bancs"]),3))
print("Précision Test: ",round(svmPOLY_gscv.score(X_test,y_test["Bancs"]),3))
print("\n")
print(svmPOLY_gscv.best_params_)
# Out:
# Fitting 5 folds for each of 704 candidates, totalling 3520 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-3c5eca735665> in <module>
#      15 #ajustement du modèle aux données
#      16 t_debut = time.time()
# ---> 17 svmPOLY_gscv.fit(X_train,y_train["Bancs"])
#      18 t_fin = time.time()
#      19
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     685                 return results
#     686
# --> 687             self._run_search(evaluate_candidates)
#     688
#     689         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1146     def _run_search(self, evaluate_candidates):
#    1147         """Search all candidates in param_grid"""
# -> 1148         evaluate_candidates(ParameterGrid(self.param_grid))
#    1149
#    1150
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     664                                for parameters, (train, test)
#     665                                in product(candidate_params,
# --> 666                                           cv.split(X, y, groups)))
#     667
#     668                 if len(out) < 1:
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# ~/.local/lib/python3.6/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /usr/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# #### f. SMV Rbf

# %%
#on crée un nouveau modèle SVM à noyau Gaussien
svmRBF = SVC(kernel='rbf',class_weight='balanced',probability=True)

#on crée un dictionnaire de toutes les valeurs que nous voulons tester
param_grid_RBF = {
                  "C": [0.01,1,10,20,50,100,500,1000,10000],
                  "gamma" : np.arange(0,1,0.05)
                 }

#on utilise gridsearch pour tester toutes les valeurs de param_grid
svmRBF_gscv = GridSearchCV(svmRBF, param_grid_RBF, cv=5, n_jobs=-1, verbose=10)

#ajustement du modèle aux données
t_debut = time.time()
svmRBF_gscv.fit(X_train,y_train["Bancs"])
t_fin = time.time()

temps_SVM_Rbf = (t_fin - t_debut)/60

print("Précision Train: ",round(svmRBF_gscv.score(X_train,y_train["Bancs"]),3))
print("Précision Test: ",round(svmRBF_gscv.score(X_test,y_test["Bancs"]),3))
print("\n")

print(svmRBF_gscv.best_params_)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:   42.7s
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:   55.4s
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 900 out of 900 | elapsed:  1.7min finished
# Précision Train:  1.0
# Précision Test:  0.479
#
#
# {'C': 1, 'gamma': 0.05}
